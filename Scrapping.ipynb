# %%
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd
import csv
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}
url = "https://meghdadit.com/productlist/laptop/?page="
urls=[]
for i in range(1,3):
    url = "https://meghdadit.com/productlist/laptop/?page="
    url = url + str(i)
    urls.append(url)

# %%
notebooks =[]
for i in urls:
    response = requests.get(i,headers=headers)
    soup = BeautifulSoup(response.text,'html.parser')
    laptops = soup.find_all('li',{'class':'col-12 col-xl-3 d-flex list-item'})
    for i in laptops :
        a = i.find('a')
        a = a['href']
        a = "https://meghdadit.com"+a
        notebooks.append(a)

# %%
csv_file = 'Book_final.csv'

with open(csv_file, 'w', newline='', encoding='utf-8') as file:
    csv_writer = csv.DictWriter(file, fieldnames=[
        'name', 'ename', 'aprice', 'sprice', 'laptop_size',
        'laptop_weight', 'laptop_type', 'Screen_size', 'Screen_type',
        'Screen_resolution', 'CPU_manufacturer', 'CPU_series', 'CPU_model', 'CPU_frequency', 'cache_memory',
        'RAM', 'RAM_type', 'hard_disk', 'internal_memory', 'graphic_manufacturer', 'graphic_model', 'graphic_memory'
    ])
    csv_writer.writeheader()
    for i in notebooks:
        response =requests.get(i,headers=headers)
        soup = BeautifulSoup(response.text,'html.parser')
        name = soup.find('h1',{'class':'d-block title-1'}).get_text()
    
        ename = soup.find('h2',{'d-block my-0 title-2'}).get_text()
    
        if soup.find('span',{'class':'d-block text-left font-weight-medium text-gray text-fa-h5'}):
            aprice = soup.find('span',{'class':'d-block text-left font-weight-medium text-gray text-fa-h5'}).get_text()
        else:
            aprice = ""
        if soup.find('span',{'class':"position-absolute font-weight-thin text-fa-h6 off"}):
            sprice = soup.find('span',{'class':"position-absolute font-weight-thin text-fa-h6 off"}).get_text()
        else : 
            sprice = ""
        if soup.find(id = 'SharedMessage_ContentPlaceHolder1_rptAttributeSet_rptAttribute_0_lblAttributeValue_0'):
            laptop_size = soup.find(id = 'SharedMessage_ContentPlaceHolder1_rptAttributeSet_rptAttribute_0_lblAttributeValue_0').get_text()
        else : 
            laptop_size = ""
        if soup.find(id = 'SharedMessage_ContentPlaceHolder1_rptAttributeSet_rptAttribute_0_lblAttributeValue_1'):
            laptop_weight = soup.find(id = 'SharedMessage_ContentPlaceHolder1_rptAttributeSet_rptAttribute_0_lblAttributeValue_1').get_text()
        else : 
            laptop_weight = ""
        if soup.find(id = 'SharedMessage_ContentPlaceHolder1_rptAttributeSet_rptAttribute_0_lblAttributeValue_2'):
            laptop_type =soup.find(id = 'SharedMessage_ContentPlaceHolder1_rptAttributeSet_rptAttribute_0_lblAttributeValue_2').get_text()
        else :
            laptop_type = "" 
        if soup.find(id = 'SharedMessage_ContentPlaceHolder1_rptAttributeSet_rptAttribute_1_lblAttributeValue_0'):
            Screen_size = soup.find(id = 'SharedMessage_ContentPlaceHolder1_rptAttributeSet_rptAttribute_1_lblAttributeValue_0').get_text()
        else : 
            Screen_size=""
        if soup.find(id = 'SharedMessage_ContentPlaceHolder1_rptAttributeSet_rptAttribute_1_lblAttributeValue_1'):
            Screen_type = soup.find(id = 'SharedMessage_ContentPlaceHolder1_rptAttributeSet_rptAttribute_1_lblAttributeValue_1').get_text()
        else : 
            Screen_type=""
        if soup.find(id = 'SharedMessage_ContentPlaceHolder1_rptAttributeSet_rptAttribute_1_lblAttributeValue_2'):
            Screen_resolution  = soup.find(id = 'SharedMessage_ContentPlaceHolder1_rptAttributeSet_rptAttribute_1_lblAttributeValue_2').get_text()
        else : 
            Screen_resolution = ''
        if soup.find(id = 'SharedMessage_ContentPlaceHolder1_rptAttributeSet_rptAttribute_2_lblAttributeValue_0'):
            CPU_manufacturer  = soup.find(id = 'SharedMessage_ContentPlaceHolder1_rptAttributeSet_rptAttribute_2_lblAttributeValue_0').get_text()
        else :
            CPU_manufacturer = ""
        if soup.find(id = 'SharedMessage_ContentPlaceHolder1_rptAttributeSet_rptAttribute_2_lblAttributeValue_1'):
            CPU_series  = soup.find(id = 'SharedMessage_ContentPlaceHolder1_rptAttributeSet_rptAttribute_2_lblAttributeValue_1').get_text()
        else : 
            CPU_series = ""
        if soup.find(id = 'SharedMessage_ContentPlaceHolder1_rptAttributeSet_rptAttribute_2_lblAttributeValue_2'):
            CPU_model = soup.find(id = 'SharedMessage_ContentPlaceHolder1_rptAttributeSet_rptAttribute_2_lblAttributeValue_2').get_text()
        else : 
            CPU_model = ''
        if soup.find(id = 'SharedMessage_ContentPlaceHolder1_rptAttributeSet_rptAttribute_2_lblAttributeValue_3'):
            CPU_frequency  = soup.find(id = 'SharedMessage_ContentPlaceHolder1_rptAttributeSet_rptAttribute_2_lblAttributeValue_3').get_text()
        else : 
            CPU_frequency = ""
        if soup.find(id = 'SharedMessage_ContentPlaceHolder1_rptAttributeSet_rptAttribute_2_lblAttributeValue_5'):
            cache_memory  = soup.find(id = 'SharedMessage_ContentPlaceHolder1_rptAttributeSet_rptAttribute_2_lblAttributeValue_5').get_text()
        else : 
            cache_memory = ""
        if soup.find(id = 'SharedMessage_ContentPlaceHolder1_rptAttributeSet_rptAttribute_3_lblAttributeValue_0'):
            RAM  = soup.find(id = 'SharedMessage_ContentPlaceHolder1_rptAttributeSet_rptAttribute_3_lblAttributeValue_0').get_text()
        else : 
            RAM = ""
        if soup.find(id = 'SharedMessage_ContentPlaceHolder1_rptAttributeSet_rptAttribute_3_lblAttributeValue_1'):
            RAM_type  = soup.find(id = 'SharedMessage_ContentPlaceHolder1_rptAttributeSet_rptAttribute_3_lblAttributeValue_1').get_text()
        else : 
            RAM_type = ""
        if soup.find(id = 'SharedMessage_ContentPlaceHolder1_rptAttributeSet_rptAttribute_4_lblAttributeValue_0'):
            hard_disk  = soup.find(id = 'SharedMessage_ContentPlaceHolder1_rptAttributeSet_rptAttribute_4_lblAttributeValue_0').get_text()
        else : 
            hard_disk = ""
        if soup.find(id = 'SharedMessage_ContentPlaceHolder1_rptAttributeSet_rptAttribute_4_lblAttributeValue_1'):
            internal_memory  = soup.find(id = 'SharedMessage_ContentPlaceHolder1_rptAttributeSet_rptAttribute_4_lblAttributeValue_1').get_text()
        else : 
            internal_memory = ""
        if soup.find(id = 'SharedMessage_ContentPlaceHolder1_rptAttributeSet_rptAttribute_5_lblAttributeValue_0'):
            graphic_manufacturer  = soup.find(id = 'SharedMessage_ContentPlaceHolder1_rptAttributeSet_rptAttribute_5_lblAttributeValue_0').get_text()
        else :
            graphic_manufacturer = ""
        if soup.find(id = 'SharedMessage_ContentPlaceHolder1_rptAttributeSet_rptAttribute_5_lblAttributeValue_1'):
            graphic_model  = soup.find(id = 'SharedMessage_ContentPlaceHolder1_rptAttributeSet_rptAttribute_5_lblAttributeValue_1').get_text()
        else : 
            graphic_model = ""
        if soup.find(id = 'SharedMessage_ContentPlaceHolder1_rptAttributeSet_rptAttribute_5_lblAttributeValue_2'):
            graphic_memory  = soup.find(id = 'SharedMessage_ContentPlaceHolder1_rptAttributeSet_rptAttribute_5_lblAttributeValue_2').get_text()
        else : 
            graphic_memory = ""
        if soup.find(id = 'SharedMessage_ContentPlaceHolder1_rptAttributeSet_rptAttribute_6_lblAttributeValue_4'):
            wifi  = soup.find(id = 'SharedMessage_ContentPlaceHolder1_rptAttributeSet_rptAttribute_6_lblAttributeValue_4').get_text()
        else : 
            wifi = ""
        if soup.find(id ='SharedMessage_ContentPlaceHolder1_rptAttributeSet_rptAttribute_6_lblAttributeValue_5'):
            Bluetooth  = soup.find(id ='SharedMessage_ContentPlaceHolder1_rptAttributeSet_rptAttribute_6_lblAttributeValue_5').get_text()
        else : 
            Bluetooth = ""
        if soup.find(id ='SharedMessage_ContentPlaceHolder1_rptAttributeSet_rptAttribute_7_lblAttributeValue_4'):
            battery  = soup.find(id ='SharedMessage_ContentPlaceHolder1_rptAttributeSet_rptAttribute_7_lblAttributeValue_4').get_text()
        else : 
            battery = ""
        if soup.find(id ='SharedMessage_ContentPlaceHolder1_rptAttributeSet_rptAttribute_7_lblAttributeValue_1'):
            webcam  =soup.find(id ='SharedMessage_ContentPlaceHolder1_rptAttributeSet_rptAttribute_7_lblAttributeValue_1').get_text()
        else : 
            webcam = ""
        if soup.find(id ='SharedMessage_ContentPlaceHolder1_rptAttributeSet_rptAttribute_7_lblAttributeValue_2'):
            OS_type  = soup.find(id ='SharedMessage_ContentPlaceHolder1_rptAttributeSet_rptAttribute_7_lblAttributeValue_2').get_text()
        else : 
            OS_type = ""
        scraped_data = {
                            'name': name,
                            'ename': ename,
                            'aprice': aprice,
                            'sprice': sprice,
                            'laptop_size': laptop_size,
                            'laptop_weight': laptop_weight,
                            'laptop_type': laptop_type,
                            'Screen_size': Screen_size,
                            'Screen_type': Screen_type,
                            'Screen_resolution': Screen_resolution,
                            'CPU_manufacturer': CPU_manufacturer,
                            'CPU_series': CPU_series,
                            'CPU_model': CPU_model,
                            'CPU_frequency': CPU_frequency,
                            'cache_memory': cache_memory,
                            'RAM': RAM,
                            'RAM_type': RAM_type,
                            'hard_disk': hard_disk,
                            'internal_memory': internal_memory,
                            'graphic_manufacturer': graphic_manufacturer,
                            'graphic_model': graphic_model,
                            'graphic_memory': graphic_memory
                            
                            }
        csv_writer.writerow(scraped_data)
